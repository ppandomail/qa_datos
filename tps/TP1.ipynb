# %% [markdown]
# # TP1
# ---

# %%
import pandas as pd
import json

# %%
df = pd.read_csv('datos.csv', sep=',')

# %%
df.head()
# Out:
#    provincia_id provincia_nombre genero edad_actual_grandes_grupos  cantidad
# 0             6     Buenos Aires      F                     0 a 17        91
# 1             6     Buenos Aires      F                    18 a 29       928
# 2             6     Buenos Aires      F                    30 a 39       816
# 3             6     Buenos Aires      F                   40 y mas      1240
# 4             6     Buenos Aires      M                     0 a 17       380

# %%
# Convertir a lista de diccionarios
json_data = df.to_dict(orient="records")

# %%
# Guardar en archivo JSON bien formateado
with open("datos.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Power BI

# %% [markdown]
# * Power BI Desktop no funciona nativamente en macOS
# * Alternativa: servicio web de Power BI (app.powerbi.com)

# %% [markdown]
# 1. Agregar datos para empezar a crear un informe
# 2. Conectarse a un origen de datos mediante URL
